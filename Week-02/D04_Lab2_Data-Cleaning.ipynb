# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the users dataset.
#
# Take a look at what is the `users.csv` separator.

# %%
users = pd.read_csv('data/users.csv',sep='#')

# %% [markdown]
# ## Check its shape
#
# See the number of rows and columns you're dealing.

# %% [markdown]
# ## Use the .head() to see some rows of your dataframe.

# %%
users.shape
# Out:
# (40503, 14)

# %%
users.info
# Out:
# <bound method DataFrame.info of           Id  Reputation         CreationDate        DisplayName  \
# 0         -1           1  2010-07-19 06:55:26          Community
# 1          2         101  2010-07-19 14:01:36       Geoff Dalgas
# 2          3         101  2010-07-19 15:34:50       Jarrod Dixon
# 3          4         101  2010-07-19 19:03:27             Emmett
# 4          5        6792  2010-07-19 19:03:57              Shane
# ...      ...         ...                  ...                ...
# 40498   6726           1  2011-10-09 13:16:20        AlexAtStack
# 40499  53426         101  2014-08-05 07:54:54  John J. Camilleri
# 40500  21468         101  2013-03-02 07:50:03           Peter L.
# 40501  54132           1  2014-08-15 10:52:25          user54132
# 40502  39943           1  2014-02-10 20:55:19        user1133128
#
#             LastAccessDate                      WebsiteUrl  \
# 0      2010-07-19 06:55:26  http://meta.stackexchange.com/
# 1      2013-11-12 22:07:23        http://stackoverflow.com
# 2      2014-08-08 06:42:58        http://stackoverflow.com
# 3      2014-01-02 09:31:02    http://minesweeperonline.com
# 4      2014-08-13 00:23:47         http://www.statalgo.com
# ...                    ...                             ...
# 40498  2012-05-18 09:32:44                             NaN
# 40499  2014-08-05 08:54:37       http://johnjcamilleri.com
# 40500  2013-03-02 07:50:03            http://www.a1qa.com/
# 40501  2014-08-15 10:52:25                             NaN
# 40502  2014-02-10 20:55:19                             NaN
#
#                  Location                                            AboutMe  \
# 0      on the server farm  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...
# 1           Corvallis, OR  <p>Developer on the StackOverflow team.  Find ...
# 2            New York, NY  <p><a href="http://blog.stackoverflow.com/2009...
# 3       San Francisco, CA  <p>currently at a startup in SF</p>\n\n<p>form...
# 4            New York, NY  <p>Quantitative researcher focusing on statist...
# ...                   ...                                                ...
# 40498                 NaN                                                NaN
# 40499  Gothenburg, Sweden  <p>Accidental computational linguist, de facto...
# 40500      Minsk, Belarus  <p>QA Manager with comprehensive, cold-blooded...
# 40501                 NaN                                                NaN
# 40502                 NaN                                                NaN
#
#        Views  UpVotes  DownVotes  AccountId   Age  \
# 0          0     5007       1920         -1   NaN
# 1         25        3          0          2  37.0
# 2         22       19          0          3  35.0
# 3         11        0          0       1998  28.0
# 4       1145      662          5      54503  35.0
# ...      ...      ...        ...        ...   ...
# 40498      0        0          0     203972   NaN
# 40499      1        2          0      34865  28.0
# 40500      1        0          0    2211454  32.0
# 40501      1        0          0    4894117   NaN
# 40502      0        0          0    1151526   NaN
#
#                                          ProfileImageUrl
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                     http://i.stack.imgur.com/d1oHX.jpg
# 4                                                    NaN
# ...                                                  ...
# 40498                                                NaN
# 40499  https://www.gravatar.com/avatar/5738c02070833b...
# 40500  http://www.gravatar.com/avatar/cbd80a5b2a5257d...
# 40501                                                NaN
# 40502  https://www.gravatar.com/avatar/8e983e68f44d99...
#
# [40503 rows x 14 columns]>

# %%
users.head()
# Out:
#    Id  Reputation         CreationDate   DisplayName       LastAccessDate  \
# 0  -1           1  2010-07-19 06:55:26     Community  2010-07-19 06:55:26
# 1   2         101  2010-07-19 14:01:36  Geoff Dalgas  2013-11-12 22:07:23
# 2   3         101  2010-07-19 15:34:50  Jarrod Dixon  2014-08-08 06:42:58
# 3   4         101  2010-07-19 19:03:27        Emmett  2014-01-02 09:31:02
# 4   5        6792  2010-07-19 19:03:57         Shane  2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# 1  <p>Developer on the StackOverflow team.  Find ...     25        3
# 2  <p><a href="http://blog.stackoverflow.com/2009...     22       19
# 3  <p>currently at a startup in SF</p>\n\n<p>form...     11        0
# 4  <p>Quantitative researcher focusing on statist...   1145      662
#
#    DownVotes  AccountId   Age                     ProfileImageUrl
# 0       1920         -1   NaN                                 NaN
# 1          0          2  37.0                                 NaN
# 2          0          3  35.0                                 NaN
# 3          0       1998  28.0  http://i.stack.imgur.com/d1oHX.jpg
# 4          5      54503  35.0                                 NaN

# %% [markdown]
# ## Get the data info.
#
# Which columns have a great number of missing values? How many space does this dataframe is occupying in your memory?

# %%
isna=pd.DataFrame( users.isna().sum(), columns = ['missing_vl'])

# %%
isna.info
# Out:
# <bound method DataFrame.info of                  missing_vl
# Id                        0
# Reputation                0
# CreationDate              0
# DisplayName               6
# LastAccessDate            0
# WebsiteUrl            32345
# Location              28772
# AboutMe               31079
# Views                     0
# UpVotes                   0
# DownVotes                 0
# AccountId                 0
# Age                   32151
# ProfileImageUrl       23963>

# %%
isna.sort_values(by='missing_vl', ascending = False).head(7)
# Out:
#                  missing_vl
# WebsiteUrl            32345
# Age                   32151
# AboutMe               31079
# Location              28772
# ProfileImageUrl       23963
# DisplayName               6
# Id                        0

# %%
isna.mean()
# Out:
# missing_vl    10594.0
# dtype: float64

# %%
# The columns with great number of missing values are: 
# WebsiteUrl
# Age
# AboutMe
# Location
# ProfileImageUrl

# %% [markdown]
# ## Rename Id column to user_id.
#
# Remember to store you results back at the dataframe.

# %%
users.rename({'Id': 'user_id'}, axis =1).head(3)
# Out:
#    user_id  Reputation         CreationDate   DisplayName  \
# 0       -1           1  2010-07-19 06:55:26     Community
# 1        2         101  2010-07-19 14:01:36  Geoff Dalgas
# 2        3         101  2010-07-19 15:34:50  Jarrod Dixon
#
#         LastAccessDate                      WebsiteUrl            Location  \
# 0  2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# 1  2013-11-12 22:07:23        http://stackoverflow.com       Corvallis, OR
# 2  2014-08-08 06:42:58        http://stackoverflow.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# 1  <p>Developer on the StackOverflow team.  Find ...     25        3
# 2  <p><a href="http://blog.stackoverflow.com/2009...     22       19
#
#    DownVotes  AccountId   Age ProfileImageUrl
# 0       1920         -1   NaN             NaN
# 1          0          2  37.0             NaN
# 2          0          3  35.0             NaN

# %%
users = users.rename({'Id': 'user_id'}, axis =1)

# %% [markdown]
# # Import the `posts.csv` dataset.
#
# Note that this is a `gzip compressed csv`. In order to read this file correctly, you'll have to read the documentation (or help) of your `pd.read_csv()` function and check the `compression` argument. Try to understand which value of `compression=...` you should put in order to read your dataframe.

# %%
posts = pd.read_csv('data/posts.csv.gzip',compression='gzip')

# %% [markdown]
# ## Perform the same as above to understand a bit of your data (head, info, shape)

# %%
posts.shape
# Out:
# (91976, 21)

# %%
posts.info
# Out:
# <bound method DataFrame.info of            Id  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0           1           1              15.0  2010-07-19 19:12:12     23
# 1           2           1              59.0  2010-07-19 19:12:57     22
# 2           3           1               5.0  2010-07-19 19:13:28     54
# 3           4           1             135.0  2010-07-19 19:13:31     13
# 4           5           2               NaN  2010-07-19 19:14:43     81
# ...       ...         ...               ...                  ...    ...
# 91971  115374           2               NaN  2014-09-13 23:45:39      2
# 91972  115375           1               NaN  2014-09-13 23:46:05      0
# 91973  115376           1               NaN  2014-09-14 01:27:54      1
# 91974  115377           2               NaN  2014-09-14 02:03:28      0
# 91975  115378           2               NaN  2014-09-14 02:09:23      0
#
#        ViewCount                                               Body  \
# 0         1278.0  <p>How should I elicit prior distributions fro...
# 1         8198.0  <p>In many different statistical methods there...
# 2         3613.0  <p>What are some valuable Statistical Analysis...
# 3         5224.0  <p>I have two groups of data.  Each with a dif...
# 4            NaN  <p>The R-project</p>\n\n<p><a href="http://www...
# ...          ...                                                ...
# 91971        NaN  <p>This grew too long for a comment, but I thi...
# 91972        9.0  <p>Assume a classification problem where there...
# 91973        5.0  <p>My goal is to create a formula that can giv...
# 91974        NaN  <p>As a practical answer to the real questions...
# 91975        NaN  <p>Decision trees are notoriously <strong>unst...
#
#        OwnerUserId      LasActivityDate  \
# 0              8.0  2010-09-15 21:08:26
# 1             24.0  2012-11-12 09:21:54
# 2             18.0  2013-05-27 14:48:36
# 3             23.0  2010-09-08 03:00:19
# 4             23.0  2010-07-19 19:21:15
# ...            ...                  ...
# 91971        805.0  2014-09-14 02:05:41
# 91972      49365.0  2014-09-14 02:09:23
# 91973      55746.0  2014-09-14 01:40:55
# 91974        805.0  2014-09-14 02:54:13
# 91975       7250.0  2014-09-14 02:09:23
#
#                                                    Title  ... AnswerCount  \
# 0                          Eliciting priors from experts  ...         5.0
# 1                                     What is normality?  ...         7.0
# 2      What are some valuable Statistical Analysis op...  ...        19.0
# 3      Assessing the significance of differences in d...  ...         5.0
# 4                                                    NaN  ...         NaN
# ...                                                  ...  ...         ...
# 91971                                                NaN  ...         NaN
# 91972  Detecting a consistent pattern in a dataset vi...  ...         1.0
# 91973  How to project video viewcount based on histor...  ...         0.0
# 91974                                                NaN  ...         NaN
# 91975                                                NaN  ...         NaN
#
#        CommentCount  FavoriteCount  LastEditorUserId         LastEditDate  \
# 0                 1           14.0               NaN                  NaN
# 1                 1            8.0              88.0  2010-08-07 17:56:44
# 2                 4           36.0             183.0  2011-02-12 05:50:03
# 3                 2            2.0               NaN                  NaN
# 4                 3            NaN              23.0  2010-07-19 19:21:15
# ...             ...            ...               ...                  ...
# 91971             2            NaN             805.0  2014-09-14 02:05:41
# 91972             0            NaN               NaN                  NaN
# 91973             2            NaN            7290.0  2014-09-14 01:40:55
# 91974             0            NaN             805.0  2014-09-14 02:54:13
# 91975             0            NaN               NaN                  NaN
#
#         CommunityOwnedDate  ParentId  ClosedDate OwnerDisplayName  \
# 0                      NaN       NaN         NaN              NaN
# 1                      NaN       NaN         NaN              NaN
# 2      2010-07-19 19:13:28       NaN         NaN              NaN
# 3                      NaN       NaN         NaN              NaN
# 4      2010-07-19 19:14:43       3.0         NaN              NaN
# ...                    ...       ...         ...              ...
# 91971                  NaN  115367.0         NaN              NaN
# 91972                  NaN       NaN         NaN              NaN
# 91973                  NaN       NaN         NaN              NaN
# 91974                  NaN  115358.0         NaN              NaN
# 91975                  NaN  115375.0         NaN              NaN
#
#       LastEditorDisplayName
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 91971                   NaN
# 91972                   NaN
# 91973                   NaN
# 91974                   NaN
# 91975                   NaN
#
# [91976 rows x 21 columns]>

# %%
posts.head()
# Out:
#    Id  PostTypeId  AcceptedAnswerId          CreaionDate  Score  ViewCount  \
# 0   1           1              15.0  2010-07-19 19:12:12     23     1278.0
# 1   2           1              59.0  2010-07-19 19:12:57     22     8198.0
# 2   3           1               5.0  2010-07-19 19:13:28     54     3613.0
# 3   4           1             135.0  2010-07-19 19:13:31     13     5224.0
# 4   5           2               NaN  2010-07-19 19:14:43     81        NaN
#
#                                                 Body  OwnerUserId  \
# 0  <p>How should I elicit prior distributions fro...          8.0
# 1  <p>In many different statistical methods there...         24.0
# 2  <p>What are some valuable Statistical Analysis...         18.0
# 3  <p>I have two groups of data.  Each with a dif...         23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...         23.0
#
#        LasActivityDate                                              Title  \
# 0  2010-09-15 21:08:26                      Eliciting priors from experts
# 1  2012-11-12 09:21:54                                 What is normality?
# 2  2013-05-27 14:48:36  What are some valuable Statistical Analysis op...
# 3  2010-09-08 03:00:19  Assessing the significance of differences in d...
# 4  2010-07-19 19:21:15                                                NaN
#
#    ... AnswerCount  CommentCount  FavoriteCount  LastEditorUserId  \
# 0  ...         5.0             1           14.0               NaN
# 1  ...         7.0             1            8.0              88.0
# 2  ...        19.0             4           36.0             183.0
# 3  ...         5.0             2            2.0               NaN
# 4  ...         NaN             3            NaN              23.0
#
#           LastEditDate   CommunityOwnedDate ParentId  ClosedDate  \
# 0                  NaN                  NaN      NaN         NaN
# 1  2010-08-07 17:56:44                  NaN      NaN         NaN
# 2  2011-02-12 05:50:03  2010-07-19 19:13:28      NaN         NaN
# 3                  NaN                  NaN      NaN         NaN
# 4  2010-07-19 19:21:15  2010-07-19 19:14:43      3.0         NaN
#
#   OwnerDisplayName LastEditorDisplayName
# 0              NaN                   NaN
# 1              NaN                   NaN
# 2              NaN                   NaN
# 3              NaN                   NaN
# 4              NaN                   NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Rename Id column to post_id and OwnerUserId to user_id.
#
# Again, remember to check that your results are correctly stored inside the dataframe.

# %%
posts = posts.rename({'Id': 'post_id', 'OwnerUserId': 'user_id'},axis=1)
posts.head(10)
# Out:
#    post_id  PostTypeId  AcceptedAnswerId          CreaionDate  Score  \
# 0        1           1              15.0  2010-07-19 19:12:12     23
# 1        2           1              59.0  2010-07-19 19:12:57     22
# 2        3           1               5.0  2010-07-19 19:13:28     54
# 3        4           1             135.0  2010-07-19 19:13:31     13
# 4        5           2               NaN  2010-07-19 19:14:43     81
# 5        6           1               NaN  2010-07-19 19:14:44    152
# 6        7           1              18.0  2010-07-19 19:15:59     76
# 7        8           1               NaN  2010-07-19 19:16:21      0
# 8        9           2               NaN  2010-07-19 19:16:27     13
# 9       10           1            1887.0  2010-07-19 19:17:47     23
#
#    ViewCount                                               Body  user_id  \
# 0     1278.0  <p>How should I elicit prior distributions fro...      8.0
# 1     8198.0  <p>In many different statistical methods there...     24.0
# 2     3613.0  <p>What are some valuable Statistical Analysis...     18.0
# 3     5224.0  <p>I have two groups of data.  Each with a dif...     23.0
# 4        NaN  <p>The R-project</p>\n\n<p><a href="http://www...     23.0
# 5    29229.0  <p>Last year, I read a blog post from <a href=...      5.0
# 6     5808.0  <p>I've been working on a new method for analy...     38.0
# 7      288.0  <p>Sorry, but the emptyness was a bit overwhel...     37.0
# 8        NaN  <p><a href="http://incanter.org/">Incanter</a>...     50.0
# 9    21925.0  <p>Many studies in the social sciences use Lik...     24.0
#
#        LasActivityDate                                              Title  \
# 0  2010-09-15 21:08:26                      Eliciting priors from experts
# 1  2012-11-12 09:21:54                                 What is normality?
# 2  2013-05-27 14:48:36  What are some valuable Statistical Analysis op...
# 3  2010-09-08 03:00:19  Assessing the significance of differences in d...
# 4  2010-07-19 19:21:15                                                NaN
# 5  2014-05-29 03:54:31  The Two Cultures: statistics vs. machine learn...
# 6  2013-12-28 06:53:10             Locating freely available data samples
# 7  2010-10-18 07:57:31  So how many staticians *does* it take to screw...
# 8  2010-07-19 19:16:27                                                NaN
# 9  2012-10-23 17:33:41  Under what conditions should Likert scales be ...
#
#    ... AnswerCount  CommentCount  FavoriteCount  LastEditorUserId  \
# 0  ...         5.0             1           14.0               NaN
# 1  ...         7.0             1            8.0              88.0
# 2  ...        19.0             4           36.0             183.0
# 3  ...         5.0             2            2.0               NaN
# 4  ...         NaN             3            NaN              23.0
# 5  ...        15.0             5          137.0           22047.0
# 6  ...        24.0             3           79.0             253.0
# 7  ...         1.0             2            NaN             449.0
# 8  ...         NaN             3            NaN               NaN
# 9  ...         4.0             4           12.0             919.0
#
#           LastEditDate   CommunityOwnedDate ParentId           ClosedDate  \
# 0                  NaN                  NaN      NaN                  NaN
# 1  2010-08-07 17:56:44                  NaN      NaN                  NaN
# 2  2011-02-12 05:50:03  2010-07-19 19:13:28      NaN                  NaN
# 3                  NaN                  NaN      NaN                  NaN
# 4  2010-07-19 19:21:15  2010-07-19 19:14:43      3.0                  NaN
# 5  2013-06-07 06:38:10  2010-08-09 13:05:50      NaN                  NaN
# 6  2013-09-26 21:50:36  2010-07-20 20:50:48      NaN                  NaN
# 7  2010-10-18 07:57:31                  NaN      NaN  2010-07-19 20:19:46
# 8                  NaN  2010-07-19 19:16:27      3.0                  NaN
# 9  2011-03-30 15:31:46                  NaN      NaN                  NaN
#
#   OwnerDisplayName LastEditorDisplayName
# 0              NaN                   NaN
# 1              NaN                   NaN
# 2              NaN                   NaN
# 3              NaN                   NaN
# 4              NaN                   NaN
# 5              NaN                   NaN
# 6              NaN                   NaN
# 7              NaN                   NaN
# 8              NaN                   NaN
# 9              NaN                   NaN
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Define new dataframes for users and posts with the following selected columns:
#
# **users columns**: user_id, Reputation, Views, UpVotes, DownVotes
# **posts columns**: post_id, Score, user_id, ViewCount, CommentCount, Body

# %%
users_columns = users[['user_id', 'Reputation', 'Views', 'UpVotes', 'DownVotes']]
users_columns.head(2)
# Out:
#    user_id  Reputation  Views  UpVotes  DownVotes
# 0       -1           1      0     5007       1920
# 1        2         101     25        3          0

# %%
posts_columns = posts[['post_id', 'Score', 'user_id', 'ViewCount', 'CommentCount', 'Body']]
posts_columns.head(2)
# Out:
#    post_id  Score  user_id  ViewCount  CommentCount  \
# 0        1     23      8.0     1278.0             1
# 1        2     22     24.0     8198.0             1
#
#                                                 Body
# 0  <p>How should I elicit prior distributions fro...
# 1  <p>In many different statistical methods there...

# %%
users_columns.info
# Out:
# <bound method DataFrame.info of        user_id  Reputation  Views  UpVotes  DownVotes
# 0           -1           1      0     5007       1920
# 1            2         101     25        3          0
# 2            3         101     22       19          0
# 3            4         101     11        0          0
# 4            5        6792   1145      662          5
# ...        ...         ...    ...      ...        ...
# 40498     6726           1      0        0          0
# 40499    53426         101      1        2          0
# 40500    21468         101      1        0          0
# 40501    54132           1      1        0          0
# 40502    39943           1      0        0          0
#
# [40503 rows x 5 columns]>

# %%
posts_columns.info
# Out:
# <bound method DataFrame.info of        post_id  Score  user_id  ViewCount  CommentCount  \
# 0            1     23      8.0     1278.0             1
# 1            2     22     24.0     8198.0             1
# 2            3     54     18.0     3613.0             4
# 3            4     13     23.0     5224.0             2
# 4            5     81     23.0        NaN             3
# ...        ...    ...      ...        ...           ...
# 91971   115374      2    805.0        NaN             2
# 91972   115375      0  49365.0        9.0             0
# 91973   115376      1  55746.0        5.0             2
# 91974   115377      0    805.0        NaN             0
# 91975   115378      0   7250.0        NaN             0
#
#                                                     Body
# 0      <p>How should I elicit prior distributions fro...
# 1      <p>In many different statistical methods there...
# 2      <p>What are some valuable Statistical Analysis...
# 3      <p>I have two groups of data.  Each with a dif...
# 4      <p>The R-project</p>\n\n<p><a href="http://www...
# ...                                                  ...
# 91971  <p>This grew too long for a comment, but I thi...
# 91972  <p>Assume a classification problem where there...
# 91973  <p>My goal is to create a formula that can giv...
# 91974  <p>As a practical answer to the real questions...
# 91975  <p>Decision trees are notoriously <strong>unst...
#
# [91976 rows x 6 columns]>

# %% [markdown]
# **Note:** Check the new posts dataframe's info. What is the most noticeable change?
#
# Explain why we have chosen only some columns of it in terms of efficiency.

# %%
# It's lighter, and brings only the relevant information

# %% [markdown]
# # Merge the new dataframes you have created, of users and posts. Create a dataframe called `posts_from_users`
#
# You will need to make an inner [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.
#
# Think carefully which should be the key(s) for your merging.

# %%
posts_from_users = pd.merge(left=users_columns,
                            right=posts_columns,
                            on='user_id')
posts_from_users
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 0           -1           1      0     5007       1920     2175      0
# 1           -1           1      0     5007       1920     8576      0
# 2           -1           1      0     5007       1920     8578      0
# 3           -1           1      0     5007       1920     8981      0
# 4           -1           1      0     5007       1920     8982      0
# ...        ...         ...    ...      ...        ...      ...    ...
# 90878    55734           1      0        0          0   115352      0
# 90879    55738          11      0        0          0   115360      2
# 90880    55742           6      0        0          0   115366      1
# 90881    55744           6      1        0          0   115370      1
# 90882    55746         106      1        0          0   115376      1
#
#        ViewCount  CommentCount  \
# 0            NaN             0
# 1            NaN             0
# 2            NaN             0
# 3            NaN             0
# 4            NaN             0
# ...          ...           ...
# 90878       16.0             0
# 90879       40.0             4
# 90880       17.0             0
# 90881       13.0             2
# 90882        5.0             2
#
#                                                     Body
# 0      <p><strong>CrossValidated</strong> is for stat...
# 1                                                    NaN
# 2                                                    NaN
# 3      <p>"Statistics" can refer variously to the (wi...
# 4      This generic tag is only rarely suitable; use ...
# ...                                                  ...
# 90878  <p>For example, I was looking at <a href="http...
# 90879  <p>Is Student's t test a Wald test?</p>\n\n<p>...
# 90880  <p>Does any standard statistical software like...
# 90881  <p>im analyzing an article for my studies with...
# 90882  <p>My goal is to create a formula that can giv...
#
# [90883 rows x 10 columns]

# %% [markdown]
# ## Check the number of duplicated rows.
#
# Remember you can sum the results of a mask to get how many numbers the True value appeared in the results. This occurs because `True` is interpreted as `1` in Python whereas `False` is interpreted as `0`.

# %%
# There are 598 duplicated rows

posts_from_users.duplicated(keep=False).sum()
# Out:
# 598

# %% [markdown]
# ## Find those duplicate values and try to understand what happened.
#
# *Hint:* You can use the argument `keep=False` from the `.duplicated()` method to bring the duplication.
#
# *Hint 2:* You can sort the values `by=['user_id', 'post_id']` to see them in order.

# %%
mask = posts_from_users.duplicated(keep=False)

posts_from_users.loc[mask,:].sort_values(by=['user_id', 'post_id'])
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 8396       760         168     13       13          0     1289      7
# 8399       760         168     13       13          0     1289      7
# 8397       760         168     13       13          0     8625      6
# 8400       760         168     13       13          0     8625      6
# 8398       760         168     13       13          0    23987      0
# ...        ...         ...    ...      ...        ...      ...    ...
# 90343    54711           4     18        0          0   114527      0
# 90368    54741          16      1        0          0   113334      3
# 90369    54741          16      1        0          0   113334      3
# 90460    54911           1      1        0          0   113691      0
# 90461    54911           1      1        0          0   113691      0
#
#        ViewCount  CommentCount  \
# 8396      1139.0             8
# 8399      1139.0             8
# 8397      1799.0             3
# 8400      1799.0             3
# 8398        62.0             3
# ...          ...           ...
# 90343       45.0             5
# 90368      122.0             9
# 90369      122.0             9
# 90460       36.0            11
# 90461       36.0            11
#
#                                                     Body
# 8396   <p>I am having difficulties to select the righ...
# 8399   <p>I am having difficulties to select the righ...
# 8397   <p>I was fiddling with PCA and LDA methods and...
# 8400   <p>I was fiddling with PCA and LDA methods and...
# 8398   <p>I was studying on a PAMI article and I have...
# ...                                                  ...
# 90343  <p>From Shapiro-Wilk's test I see that the res...
# 90368  <p>I am confused on what I have read about the...
# 90369  <p>I am confused on what I have read about the...
# 90460  <p>I extract data related to a movie by sentim...
# 90461  <p>I extract data related to a movie by sentim...
#
# [598 rows x 10 columns]

# %% [markdown]
# ## Should you drop it? If you think it is reasonable to drop it, then drop it.
#
# Think: How would you correct it in the first place? That is, what was wrong in the first place?
#
# *Hint:* There's a pandas method to drop duplicates. If you wanted to do it by hand, you could select the indexes of the duplicated values and `.drop()` it.

# %%
# número de comentários repetidos na DataFrame de posts_columns:

posts_columns.duplicated(subset=['Body']).sum()
# Out:
# 233

# %% [markdown]
# -> Yes, the duplicated rows should be droped, because they store exactly the same information.
# What was wrong in the first place is that in the posts DataFrame, the data was already duplicated.

# %%
# droping duplicates:

posts_from_users_dropado = posts_from_users.drop_duplicates()

# %%
posts_from_users_dropado
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 0           -1           1      0     5007       1920     2175      0
# 1           -1           1      0     5007       1920     8576      0
# 2           -1           1      0     5007       1920     8578      0
# 3           -1           1      0     5007       1920     8981      0
# 4           -1           1      0     5007       1920     8982      0
# ...        ...         ...    ...      ...        ...      ...    ...
# 90878    55734           1      0        0          0   115352      0
# 90879    55738          11      0        0          0   115360      2
# 90880    55742           6      0        0          0   115366      1
# 90881    55744           6      1        0          0   115370      1
# 90882    55746         106      1        0          0   115376      1
#
#        ViewCount  CommentCount  \
# 0            NaN             0
# 1            NaN             0
# 2            NaN             0
# 3            NaN             0
# 4            NaN             0
# ...          ...           ...
# 90878       16.0             0
# 90879       40.0             4
# 90880       17.0             0
# 90881       13.0             2
# 90882        5.0             2
#
#                                                     Body
# 0      <p><strong>CrossValidated</strong> is for stat...
# 1                                                    NaN
# 2                                                    NaN
# 3      <p>"Statistics" can refer variously to the (wi...
# 4      This generic tag is only rarely suitable; use ...
# ...                                                  ...
# 90878  <p>For example, I was looking at <a href="http...
# 90879  <p>Is Student's t test a Wald test?</p>\n\n<p>...
# 90880  <p>Does any standard statistical software like...
# 90881  <p>im analyzing an article for my studies with...
# 90882  <p>My goal is to create a formula that can giv...
#
# [90584 rows x 10 columns]

# %% [markdown]
# ## 10. How many missing values do you have in your merged dataframe? On which columns?

# %% [markdown]
# -> there are 48,396 missing values in the following columns: [ViewCount, Body]

# %%
posts_from_users_dropado.isna().sum()
# Out:
# user_id             0
# Reputation          0
# Views               0
# UpVotes             0
# DownVotes           0
# post_id             0
# Score               0
# ViewCount       48396
# CommentCount        0
# Body              220
# dtype: int64

# %% [markdown]
# ## Select only the rows in which there at least some missing values.

# %%
mask = posts_from_users_dropado.isna().any(axis=1)


missing = posts_from_users_dropado.loc[mask,:]

missing
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 0           -1           1      0     5007       1920     2175      0
# 1           -1           1      0     5007       1920     8576      0
# 2           -1           1      0     5007       1920     8578      0
# 3           -1           1      0     5007       1920     8981      0
# 4           -1           1      0     5007       1920     8982      0
# ...        ...         ...    ...      ...        ...      ...    ...
# 90817    55605           1      2        0          0   115106      0
# 90820    55609           1      1        0          0   115115      2
# 90827    55621           1      1        0          0   115213      0
# 90835    55637          26      4        0          0   115170      1
# 90874    55729          16      1        0          0   115338      0
#
#        ViewCount  CommentCount  \
# 0            NaN             0
# 1            NaN             0
# 2            NaN             0
# 3            NaN             0
# 4            NaN             0
# ...          ...           ...
# 90817        NaN             0
# 90820        NaN             0
# 90827        NaN             0
# 90835        NaN             0
# 90874        NaN             0
#
#                                                     Body
# 0      <p><strong>CrossValidated</strong> is for stat...
# 1                                                    NaN
# 2                                                    NaN
# 3      <p>"Statistics" can refer variously to the (wi...
# 4      This generic tag is only rarely suitable; use ...
# ...                                                  ...
# 90817  <p>Recasting this as a time-to-event problem, ...
# 90820  <p>This is my favourite:</p>\n\n<p>"To be sure...
# 90827  <p>Here is the part that explains answer to yo...
# 90835  <p>When you say class, I hope you mean 'output...
# 90874  <p>All items are not solved fully correctly in...
#
# [48396 rows x 10 columns]

# %% [markdown]
# ## You will need to make something with missing values.  Will you clean or fill them in?
#
# Pay attention. There can be different reasons for the missings numbers. Look at the `user_id` of some of them, look at the body of the message. Which ones you're sure of what should be and which one can you infer? Don't hurry up, take a look at your data.

# %%
mask_1 = (missing.CommentCount == 0)
mask_2 = (missing.CommentCount > 0)

# %%
missing.loc[mask_2,:].sample(10)
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 9196       805       65272   5680     7035        143    59790      1
# 32951     6961        2413    266      152         11    58983      2
# 25938     4505       25123   1245      582          4    45396      4
# 77160    35917        1423    123       94          2    84117      1
# 4863       442        6431    973      857         21     2780      1
# 37528     8013        7972    662      108          6    96631      1
# 74714    32036        7227    991     2664        143    80929      0
# 27160     4843         543    102       32          0    27234      1
# 5741       582        2400    293      692         23    14801      0
# 40259     9007        1318    309      456         31    27220      7
#
#        ViewCount  CommentCount  \
# 9196         NaN             2
# 32951        NaN             2
# 25938        NaN             1
# 77160        NaN             5
# 4863         NaN             1
# 37528        NaN             8
# 74714        NaN             2
# 27160        NaN             1
# 5741         NaN             1
# 40259        NaN             7
#
#                                                     Body
# 9196   <p>If I understand it right, Mallows distance ...
# 32951  <p>Under a simple null hypothesis, the samplin...
# 25938  <p>For a single covariance you only need the b...
# 77160  <p>I'm not sure there is ever a reason to use ...
# 4863   <p>Normally you always find ways to convert ef...
# 37528  <p>To be formal about it, there are very abstr...
# 74714  <p><strong>Edit: might not apply</strong> beca...
# 27160  <p>A method such as that used in unsupervised ...
# 5741   <p>You could use <code>image.smooth</code> in ...
# 40259  <p>The answer is almost always: <strong>report...

# %%
missing.sort_values(by='CommentCount', ascending=False)
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 44796    11032       22275   7395     2619         42    31038      6
# 13987     1124        3000    456      140          7     2365      5
# 79749    38102         208     28       43          0    92246     -5
# 8604       795        5606    967     1547          8     6605     30
# 27363     4856       17791   5927     2122        412    30160     12
# ...        ...         ...    ...      ...        ...      ...    ...
# 31952     6633        9429   1534      167         88    43705      8
# 31949     6633        9429   1534      167         88    40567      2
# 31935     6633        9429   1534      167         88    27653      2
# 31934     6633        9429   1534      167         88    27487      1
# 90874    55729          16      1        0          0   115338      0
#
#        ViewCount  CommentCount  \
# 44796        NaN            45
# 13987        NaN            41
# 79749        NaN            41
# 8604         NaN            37
# 27363        NaN            35
# ...          ...           ...
# 31952        NaN             0
# 31949        NaN             0
# 31935        NaN             0
# 31934        NaN             0
# 90874        NaN             0
#
#                                                     Body
# 44796  <p>Consistency of an estimator means that as t...
# 13987  <p>The problem starts with your sentence :</p>...
# 79749  <p>Any paper that disproves the nil null hypot...
# 8604   <p>for some reason, people have difficulty gra...
# 27363  <p>It is true that each element of a multivari...
# ...                                                  ...
# 31952  <p>The calculation of such probabilities has b...
# 31949  <p>Yes, the log likelihood ratio <em>must</em>...
# 31935  <p>Speaking from an engineering viewpoint, the...
# 31934  <p>For <em>any</em> random variables $X$ and $...
# 90874  <p>All items are not solved fully correctly in...
#
# [48396 rows x 10 columns]

# %% [markdown]
# -> Answer:\
# I'm sure that the missing values of the ViewCount column which CommentCounts are 0, must be filled in as zero.
# What I could infer is that, as there are no zero values in this column, the 'NaN' must be 'zero'.

# %% [markdown]
# ## Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
# All the missing values from the ViewCount column must be filled in by zero

mask = posts_from_users_dropado.isna().any(axis=1)
posts_from_users_dropado.loc[mask,'ViewCount'] = 0
# Out:
# /Users/serachung/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
posts_from_users_dropado
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 0           -1           1      0     5007       1920     2175      0
# 1           -1           1      0     5007       1920     8576      0
# 2           -1           1      0     5007       1920     8578      0
# 3           -1           1      0     5007       1920     8981      0
# 4           -1           1      0     5007       1920     8982      0
# ...        ...         ...    ...      ...        ...      ...    ...
# 90878    55734           1      0        0          0   115352      0
# 90879    55738          11      0        0          0   115360      2
# 90880    55742           6      0        0          0   115366      1
# 90881    55744           6      1        0          0   115370      1
# 90882    55746         106      1        0          0   115376      1
#
#        ViewCount  CommentCount  \
# 0            0.0             0
# 1            0.0             0
# 2            0.0             0
# 3            0.0             0
# 4            0.0             0
# ...          ...           ...
# 90878       16.0             0
# 90879       40.0             4
# 90880       17.0             0
# 90881       13.0             2
# 90882        5.0             2
#
#                                                     Body
# 0      <p><strong>CrossValidated</strong> is for stat...
# 1                                                    NaN
# 2                                                    NaN
# 3      <p>"Statistics" can refer variously to the (wi...
# 4      This generic tag is only rarely suitable; use ...
# ...                                                  ...
# 90878  <p>For example, I was looking at <a href="http...
# 90879  <p>Is Student's t test a Wald test?</p>\n\n<p>...
# 90880  <p>Does any standard statistical software like...
# 90881  <p>im analyzing an article for my studies with...
# 90882  <p>My goal is to create a formula that can giv...
#
# [90584 rows x 10 columns]

# %%
# All the missing values from the Body column must be filled in by an empty string

mask = posts_from_users_dropado.isna().any(axis=1)
posts_from_users_dropado.loc[mask,'Body'] = 'empty'
# Out:
# /Users/serachung/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
posts_from_users_dropado
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 0           -1           1      0     5007       1920     2175      0
# 1           -1           1      0     5007       1920     8576      0
# 2           -1           1      0     5007       1920     8578      0
# 3           -1           1      0     5007       1920     8981      0
# 4           -1           1      0     5007       1920     8982      0
# ...        ...         ...    ...      ...        ...      ...    ...
# 90878    55734           1      0        0          0   115352      0
# 90879    55738          11      0        0          0   115360      2
# 90880    55742           6      0        0          0   115366      1
# 90881    55744           6      1        0          0   115370      1
# 90882    55746         106      1        0          0   115376      1
#
#        ViewCount  CommentCount  \
# 0            0.0             0
# 1            0.0             0
# 2            0.0             0
# 3            0.0             0
# 4            0.0             0
# ...          ...           ...
# 90878       16.0             0
# 90879       40.0             4
# 90880       17.0             0
# 90881       13.0             2
# 90882        5.0             2
#
#                                                     Body
# 0      <p><strong>CrossValidated</strong> is for stat...
# 1                                                  empty
# 2                                                  empty
# 3      <p>"Statistics" can refer variously to the (wi...
# 4      This generic tag is only rarely suitable; use ...
# ...                                                  ...
# 90878  <p>For example, I was looking at <a href="http...
# 90879  <p>Is Student's t test a Wald test?</p>\n\n<p>...
# 90880  <p>Does any standard statistical software like...
# 90881  <p>im analyzing an article for my studies with...
# 90882  <p>My goal is to create a formula that can giv...
#
# [90584 rows x 10 columns]

# %% [markdown]
# # Bonus 1: (filtering) What is the average number of comments for users who are above the average reputation?
#
# *Hint:* Calculate the average of the user Reputation. Store it in a variable called `avg_reputation` and then use that variable for filtering the dataset and generating the results for each case (for the case in which `Reputation > {avg_reputation}` and etc.
#
# *Hint 2:* You could create a variable based on that condition and use the group by function perform the task above.

# %%
avg_reputation = posts_from_users_dropado.Reputation.mean()
avg_reputation
# Out:
# 6282.395411993288

# %%
mask = posts_from_users_dropado.Reputation > avg_reputation
posts_from_users_dropado.loc[mask,:]
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 211          5        6792   1145      662          5        6    152
# 212          5        6792   1145      662          5       12     20
# 213          5        6792   1145      662          5       32     12
# 214          5        6792   1145      662          5       49      6
# 215          5        6792   1145      662          5       64      6
# ...        ...         ...    ...      ...        ...      ...    ...
# 74959    32036        7227    991     2664        143   111822      3
# 74960    32036        7227    991     2664        143   113074      1
# 74961    32036        7227    991     2664        143   113379      2
# 74962    32036        7227    991     2664        143   113527      2
# 74963    32036        7227    991     2664        143   114107      0
#
#        ViewCount  CommentCount  \
# 211      29229.0             5
# 212          0.0             1
# 213          0.0             0
# 214          0.0             0
# 215          0.0             0
# ...          ...           ...
# 74959        0.0             2
# 74960        0.0             0
# 74961        0.0             0
# 74962        0.0             7
# 74963        0.0             5
#
#                                                     Body
# 211    <p>Last year, I read a blog post from <a href=...
# 212    <p>See my response to <a href="http://stackove...
# 213    <p>I recommend R (see <a href="http://cran.r-p...
# 214    <p>You don't need to install any packages beca...
# 215    <p>Yes, there are many methods.  You would nee...
# ...                                                  ...
# 74959  <p>I would work on trying to get the bifactor ...
# 74960  <p>The Mann–Whitney–Wilcoxon test is the simpl...
# 74961  <p>Categorical variables have finite sets of d...
# 74962  <p>No. Age is a continuous variable and should...
# 74963  <p>When modeling financial data, one should of...
#
# [18942 rows x 10 columns]

# %%
# The average number of comments for users above avg reputation is of 2.09
mask = posts_from_users_dropado.Reputation > avg_reputation
posts_from_users_dropado.loc[mask,['CommentCount']].mean()
# Out:
# CommentCount    2.087689
# dtype: float64

# %% [markdown]
# # Bonus 2: (grouping) Group your dataframe by the Reputation of your user. Calculate the mean value of ViewCount and CommentCount for each reputation value.
#
# Suppose the missing values on ViewCount are due a systemic error and you wanted to guess what values should have been there in the first place, but the system abended.
#
# Would that be an interesting candidate for inputting the value for the missing `ViewCount` values? If so, input it with these values.

# %%
# The average number and view of comments for users above avg reputation is : 
mask = posts_from_users_dropado.Reputation > avg_reputation

posts_from_users_dropado.loc[mask,['Reputation','CommentCount','ViewCount']].groupby(by='Reputation',as_index=False).mean()
# Out:
#     Reputation  CommentCount    ViewCount
# 0         6431      2.206107   574.564885
# 1         6461      1.880952     3.321429
# 2         6524      2.307692    51.582418
# 3         6764      2.115702   738.000000
# 4         6792      1.581197  1292.914530
# 5         6906      1.965116    46.145349
# 6         7227      1.643123     1.319703
# 7         7246      2.337423    33.993865
# 8         7461      1.781746    28.833333
# 9         7663      1.846715    15.587591
# 10        7931      1.590909     5.704545
# 11        7972      2.287500    13.012500
# 12        8009      1.920000     0.000000
# 13        8045      2.136364   118.598485
# 14        8164      1.730435     6.643478
# 15        8236      1.925134    23.711230
# 16        8635      1.703608    14.456186
# 17        8772      2.076923     0.000000
# 18        8814      1.744094     3.712598
# 19        9429      1.590476    14.038095
# 20        9604      1.884058   297.047101
# 21        9800      2.211454    20.383260
# 22       10470      1.815884     2.815884
# 23       10476      2.467066    27.413174
# 24       10647      3.112403    66.748062
# 25       10690      1.568966     0.910345
# 26       11489      1.864151   115.177358
# 27       11520      2.213675     0.000000
# 28       11631      1.694118    14.305882
# 29       11860      2.517134    23.105919
# 30       12813      1.665385     0.000000
# 31       13478      1.971053    12.615789
# 32       13647      3.680851     0.000000
# 33       13806      2.153623     0.000000
# 34       13898      2.094406    53.104895
# 35       14082      1.737463    51.206490
# 36       15236      1.710327     4.526448
# 37       16108      2.510791     5.551559
# 38       17791      3.172932    11.462406
# 39       18088      2.338843    14.903581
# 40       18187      1.953678    16.376022
# 41       18283      2.034130   320.160410
# 42       19585      2.244444     5.935556
# 43       22275      2.978261    10.249482
# 44       22625      1.344828   395.215010
# 45       25123      1.366112     0.000000
# 46       31170      1.668122    40.500000
# 47       37083      1.866989     8.718259
# 48       44152      2.013767     8.951189
# 49       65272      2.287209     2.654070
# 50       87393      2.544020     3.958472

# %% [markdown]
# Would that be an interesting candidate for inputting the value for the missing ViewCount values? If so, input it with these values.

# %%
new_posts_users = posts_from_users.drop_duplicates()
new_posts_users
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 0           -1           1      0     5007       1920     2175      0
# 1           -1           1      0     5007       1920     8576      0
# 2           -1           1      0     5007       1920     8578      0
# 3           -1           1      0     5007       1920     8981      0
# 4           -1           1      0     5007       1920     8982      0
# ...        ...         ...    ...      ...        ...      ...    ...
# 90878    55734           1      0        0          0   115352      0
# 90879    55738          11      0        0          0   115360      2
# 90880    55742           6      0        0          0   115366      1
# 90881    55744           6      1        0          0   115370      1
# 90882    55746         106      1        0          0   115376      1
#
#        ViewCount  CommentCount  \
# 0            NaN             0
# 1            NaN             0
# 2            NaN             0
# 3            NaN             0
# 4            NaN             0
# ...          ...           ...
# 90878       16.0             0
# 90879       40.0             4
# 90880       17.0             0
# 90881       13.0             2
# 90882        5.0             2
#
#                                                     Body
# 0      <p><strong>CrossValidated</strong> is for stat...
# 1                                                    NaN
# 2                                                    NaN
# 3      <p>"Statistics" can refer variously to the (wi...
# 4      This generic tag is only rarely suitable; use ...
# ...                                                  ...
# 90878  <p>For example, I was looking at <a href="http...
# 90879  <p>Is Student's t test a Wald test?</p>\n\n<p>...
# 90880  <p>Does any standard statistical software like...
# 90881  <p>im analyzing an article for my studies with...
# 90882  <p>My goal is to create a formula that can giv...
#
# [90584 rows x 10 columns]

# %%
# average viewcount per reputation

# above average:
mask_aavg = new_posts_users.Reputation > avg_reputation

# below average:
mask_bavg = new_posts_users.Reputation < avg_reputation

# all missing values in the ViewCount column:
mask2 = new_posts_users.ViewCount.isna()

# there are 2 values to fill in the missing values in the Viewcounts columns, calculated by reputation category:
abv_avg = new_posts_users.loc[mask_aavg,'ViewCount'].mean()
blw_avg = new_posts_users.loc[mask_bavg,'ViewCount'].mean()

# %%
# all missing values for reputations below average:

new_posts_users.loc[(mask2 & mask_aavg),'ViewCount'] = abv_avg
# Out:
# /Users/serachung/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
new_posts_users.loc[(mask2 & mask_bavg),'ViewCount'] = blw_avg

# %%
new_posts_users
# Out:
#        user_id  Reputation  Views  UpVotes  DownVotes  post_id  Score  \
# 0           -1           1      0     5007       1920     2175      0
# 1           -1           1      0     5007       1920     8576      0
# 2           -1           1      0     5007       1920     8578      0
# 3           -1           1      0     5007       1920     8981      0
# 4           -1           1      0     5007       1920     8982      0
# ...        ...         ...    ...      ...        ...      ...    ...
# 90878    55734           1      0        0          0   115352      0
# 90879    55738          11      0        0          0   115360      2
# 90880    55742           6      0        0          0   115366      1
# 90881    55744           6      1        0          0   115370      1
# 90882    55746         106      1        0          0   115376      1
#
#         ViewCount  CommentCount  \
# 0      541.941608             0
# 1      541.941608             0
# 2      541.941608             0
# 3      541.941608             0
# 4      541.941608             0
# ...           ...           ...
# 90878   16.000000             0
# 90879   40.000000             4
# 90880   17.000000             0
# 90881   13.000000             2
# 90882    5.000000             2
#
#                                                     Body
# 0      <p><strong>CrossValidated</strong> is for stat...
# 1                                                    NaN
# 2                                                    NaN
# 3      <p>"Statistics" can refer variously to the (wi...
# 4      This generic tag is only rarely suitable; use ...
# ...                                                  ...
# 90878  <p>For example, I was looking at <a href="http...
# 90879  <p>Is Student's t test a Wald test?</p>\n\n<p>...
# 90880  <p>Does any standard statistical software like...
# 90881  <p>im analyzing an article for my studies with...
# 90882  <p>My goal is to create a formula that can giv...
#
# [90584 rows x 10 columns]

# %% [markdown]
# ## refs

# %% [markdown]
# Sample database used: https://relational.fit.cvut.cz/dataset/Stats
#
# Stack-overflow database: https://www.brentozar.com/archive/2015/10/how-to-download-the-stack-overflow-database-via-bittorrent/
